# %% [markdown]
# ### Configuration

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
spark = SparkSession\
        .builder\
        .appName("aggregation")\
        .config("spark.mongodb.input.uri","mongodb://127.0.0.1:27017/spark.practice")\
        .config("spark.mongodb.output.uri","mongodb://127.0.0.1:27017/spark.practice")\
        .config("spark.jars.packages","org.mongodb.spark:mongo-spark-connector_2.12:3.0.1")\
        .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-JOJHKCD:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>aggregation</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
path= "../../data/"

df_list =[]
for filename in os.listdir(path):
    if filename.endswith(".csv"):
        splitter = filename.split('.')
        df_name = splitter[0]
        df = spark.read.csv(path+filename,inferSchema=True,header=True)
        exec(df_name +"=df")
        df_list.append(df_name)

# %%
df_list
# Out:
# ['fifa19',
#  'googleplaystore',
#  'nyc_air_bnb',
#  'pga_tour_historical',
#  'rec_crime_pfa',
#  'Rep_vs_Dem_tweets',
#  'students',
#  'supermarket_sales',
#  'Weather',
#  'youtubevideos',
#  'zomato']

# %%
supermarket_sales.printSchema()
# Out:
# root
#  |-- Invoice ID: string (nullable = true)
#  |-- Branch: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Customer type: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Product line: string (nullable = true)
#  |-- Unit price: double (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- Tax 5%: double (nullable = true)
#  |-- Total: double (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Time: string (nullable = true)
#  |-- Payment: string (nullable = true)
#  |-- cogs: double (nullable = true)
#  |-- gross margin percentage: double (nullable = true)
#  |-- gross income: double (nullable = true)
#  |-- Rating: double (nullable = true)

# %%
supermarket_sales.limit(3).toPandas()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4

# %% [markdown]
# ### Write this dataframe TO Mongo

# %%
supermarket_sales.write.format("mongo").mode("append").option("database","spark").option("collection","supermarket").save()


# student.write.format("mongo").mode("append").option("database",
# "spark").option("collection", "practice").save()

# %% [markdown]
# ### Load the same dataset FROM Mongo

# %%
df = spark.read.format("mongo").option("spark.mongodb.input.uri","mongodb://127.0.0.1/spark.supermarket").load()

# %%
df.toPandas()
# Out:
#     Branch       City Customer type       Date  Gender   Invoice ID  \
# 0        A     Yangon        Member   1/5/2019  Female  750-67-8428
# 1        C  Naypyitaw        Normal   3/8/2019  Female  226-31-3081
# 2        A     Yangon        Normal   3/3/2019    Male  631-41-3108
# 3        A     Yangon        Member  1/27/2019    Male  123-19-1176
# 4        A     Yangon        Normal   2/8/2019    Male  373-73-7910
# ..     ...        ...           ...        ...     ...          ...
# 995      C  Naypyitaw        Normal  1/29/2019    Male  233-67-5758
# 996      B   Mandalay        Normal   3/2/2019  Female  303-96-2227
# 997      A     Yangon        Member   2/9/2019    Male  727-02-1313
# 998      A     Yangon        Normal  2/22/2019    Male  347-56-2442
# 999      A     Yangon        Member  2/18/2019  Female  849-09-3807
#
#          Payment            Product line  Quantity  Rating   Tax 5%   Time  \
# 0        Ewallet       Health and beauty         7     9.1  26.1415  13:08
# 1           Cash  Electronic accessories         5     9.6   3.8200  10:29
# 2    Credit card      Home and lifestyle         7     7.4  16.2155  13:23
# 3        Ewallet       Health and beauty         8     8.4  23.2880  20:33
# 4        Ewallet       Sports and travel         7     5.3  30.2085  10:37
# ..           ...                     ...       ...     ...      ...    ...
# 995      Ewallet       Health and beauty         1     6.2   2.0175  13:46
# 996      Ewallet      Home and lifestyle        10     4.4  48.6900  17:16
# 997         Cash      Food and beverages         1     7.7   1.5920  13:22
# 998         Cash      Home and lifestyle         1     4.1   3.2910  15:33
# 999         Cash     Fashion accessories         7     6.6  30.9190  13:28
#
#          Total  Unit price                          _id    cogs  gross income  \
# 0     548.9715       74.69  (6144311c7a60c3187fbc1986,)  522.83       26.1415
# 1      80.2200       15.28  (6144311c7a60c3187fbc1987,)   76.40        3.8200
# 2     340.5255       46.33  (6144311c7a60c3187fbc1988,)  324.31       16.2155
# 3     489.0480       58.22  (6144311c7a60c3187fbc1989,)  465.76       23.2880
# 4     634.3785       86.31  (6144311c7a60c3187fbc198a,)  604.17       30.2085
# ..         ...         ...                          ...     ...           ...
# 995    42.3675       40.35  (6144311c7a60c3187fbc1d69,)   40.35        2.0175
# 996  1022.4900       97.38  (6144311c7a60c3187fbc1d6a,)  973.80       48.6900
# 997    33.4320       31.84  (6144311c7a60c3187fbc1d6b,)   31.84        1.5920
# 998    69.1110       65.82  (6144311c7a60c3187fbc1d6c,)   65.82        3.2910
# 999   649.2990       88.34  (6144311c7a60c3187fbc1d6d,)  618.38       30.9190
#
#      gross margin percentage
# 0                   4.761905
# 1                   4.761905
# 2                   4.761905
# 3                   4.761905
# 4                   4.761905
# ..                       ...
# 995                 4.761905
# 996                 4.761905
# 997                 4.761905
# 998                 4.761905
# 999                 4.761905
#
# [1000 rows x 18 columns]

# %% [markdown]
# ### Load the dataset using Aggregation

# %%
#specify pipeline you want to apply
pipeline1 = {"$match":{"Gender":"Male","Payment":"Ewallet"}}
pipeline2 = {"$project":{"Branch":1,"City":1,"_id":0,"Gender":1}}            

df1 = spark.read.format("mongo")\
        .option("spark.mongodb.input.uri","mongodb://127.0.0.1/spark.supermarket")\
        .option("pipeline",[pipeline1,pipeline2]).load()

# %%
df1.toPandas()
# Out:
#     Branch       City Gender
# 0        A     Yangon   Male
# 1        A     Yangon   Male
# 2        C  Naypyitaw   Male
# 3        A     Yangon   Male
# 4        C  Naypyitaw   Male
# ..     ...        ...    ...
# 180      B   Mandalay   Male
# 181      C  Naypyitaw   Male
# 182      A     Yangon   Male
# 183      B   Mandalay   Male
# 184      C  Naypyitaw   Male
#
# [185 rows x 3 columns]
